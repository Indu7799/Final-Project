# %%
import pandas as pandas
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Importing the dataset
X = pandas.read_csv("train.csv")
Y = pandas.read_csv("test.csv")

# %%
Y
# Out:
#              id  S1  C1  S2  C2  S3  C3  S4  C4  S5  C5
# 0             1   1  10   2   2   3   3   3   8   1   1
# 1             2   2  13   3   5   3   7   4   6   1   4
# 2             3   1   3   1  11   2   8   2   1   2   4
# 3             4   1   6   3   3   4   7   1   8   3  11
# 4             5   2  10   3   4   1   6   2  12   2   6
# 5             6   1   4   3  10   2  11   2   6   1   7
# 6             7   1  10   3   8   1   4   3  11   3   9
# 7             8   2  11   3   8   1   1   1  11   2   3
# 8             9   3   4   1   1   1   3   3   5   3   6
# 9            10   3  12   2   1   1   3   1   2   3  10
# 10           11   1   7   3   1   4   8   4  10   3  11
# 11           12   2   3   2  11   3   9   1  10   2   5
# 12           13   1   4   2  13   4   6   4   8   4   5
# 13           14   4   7   4   2   3   3   1   4   1   1
# 14           15   4   8   3  10   4  11   3   5   1  12
# 15           16   4  11   1  10   1   3   1   2   4   5
# ...

# %%
#Checking for Null Values
Y[Y.id.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %% [markdown]
# ##### There are no missing or null values in the dataset. However, I will be checking for the missing values for every variable in the dataset.

# %%
#Checking null values for the variable S1
Y[Y.S1.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar chart for S1
Y.S1.value_counts().plot(kind = "bar")

# %%
#Checking null values for C1
Y[Y.C1.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for C1 
Y.C1.value_counts().plot(kind="bar")

# %%
#Checking null values for S2
Y[Y.S2.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for S2
Y.S2.value_counts().plot(kind = "bar")

# %%
#Checking null values for C2
Y[Y.C2.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for C2
Y.C2.value_counts().plot(kind="bar")

# %%
#Checking null values for S3
Y[Y.S3.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for S3
Y.S3.value_counts().plot(kind = "bar")

# %%
#Checking null values for C3
Y[Y.C3.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for C3
Y.C3.value_counts().plot(kind = "bar")

# %%
#Checking null values for S4
Y[Y.S4.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for S4
Y.S4.value_counts().plot(kind = "bar")

# %%
#Checking null values for C4
Y[Y.C4.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for C4
Y.C4.value_counts().plot(kind = "bar")

# %%
#Checking null values for S5
Y[Y.S5.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for S5
Y.S5.value_counts().plot(kind="bar")

# %%
#Checking null values for C5
Y[Y.C5.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, S1, C1, S2, C2, S3, C3, S4, C4, S5, C5]
# Index: []

# %%
#Bar Chart for C5
Y.C5.value_counts().plot(kind="bar")

# %%
X.shape
# Out:
# (25010, 11)

# %%
#post data analysis
import pandas as pandas
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pandas.read_csv("result.csv")

# %%
df.columns
# Out:
# Index([u'id', u'hand'], dtype='object')

# %%
df
# Out:
#              id  hand
# 0             1     0
# 1             2     0
# 2             3     0
# 3             4     0
# 4             5     0
# 5             6     0
# 6             7     0
# 7             8     0
# 8             9     0
# 9            10     0
# 10           11     0
# 11           12     0
# 12           13     0
# 13           14     0
# 14           15     0
# 15           16     0
# 16           17     0
# 17           18     0
# 18           19     0
# 19           20     0
# 20           21     0
# 21           22     0
# 22           23     0
# 23           24     1
# 24           25     0
# 25           26     0
# 26           27     2
# 27           28     0
# 28           29     0
# 29           30     0
# ...         ...   ...
# 999970   999971     1
# 999971   999972     0
# 999972   999973     0
# 999973   999974     1
# 999974   999975     0
# 999975   999976     0
# 999976   999977     0
# 999977   999978     1
# 999978   999979     0
# ...

# %%
df.isnull()
# Out:
#            id   hand
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# 5       False  False
# 6       False  False
# 7       False  False
# 8       False  False
# 9       False  False
# 10      False  False
# 11      False  False
# 12      False  False
# 13      False  False
# 14      False  False
# 15      False  False
# 16      False  False
# 17      False  False
# 18      False  False
# 19      False  False
# 20      False  False
# 21      False  False
# 22      False  False
# 23      False  False
# 24      False  False
# 25      False  False
# 26      False  False
# 27      False  False
# 28      False  False
# 29      False  False
# ...       ...    ...
# 999970  False  False
# 999971  False  False
# 999972  False  False
# 999973  False  False
# 999974  False  False
# 999975  False  False
# 999976  False  False
# 999977  False  False
# 999978  False  False
# 999979  False  False
# 999980  False  False
# ...

# %%
df.describe()
# Out:
#                    id            hand
# count  1000000.000000  1000000.000000
# mean    500000.500000        0.234480
# std     288675.278932        0.511229
# min          1.000000        0.000000
# 25%     250000.750000        0.000000
# 50%     500000.500000        0.000000
# 75%     750000.250000        0.000000
# max    1000000.000000        7.000000

# %%
df.hand.value_counts().plot(kind="bar")
